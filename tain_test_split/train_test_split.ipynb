# %%
import pandas as pd

# %%
df = pd.read_csv("carprices.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])
plt.show()

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])
plt.show()

# %%
X = df[['Mileage','Age(yrs)']]

# %%
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size = 0.3)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 17    69000         5
# 10    83000         7
# 0     69000         6
# 5     59000         5
# 12    59000         5
# 18    87600         8
# 13    58780         4
# 6     52000         5
# 9     67000         6
# 11    79000         7
# 7     72000         6
# 16    28000         2
# 4     46000         4
# 3     22500         2

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 8     91000         8
# 2     57000         5
# 14    82450         7
# 1     35000         3
# 15    25400         3
# 19    52000         5

# %%
y_train
# Out:
# 17    19700
# 10    18700
# 0     18000
# 5     26750
# 12    26000
# 18    12800
# 13    27500
# 6     32000
# 9     22000
# 11    19500
# 7     19300
# 16    35500
# 4     31500
# 3     40000
# Name: Sell Price($), dtype: int64

# %%
y_test
# Out:
# 8     12000
# 2     26100
# 14    19400
# 1     34000
# 15    35000
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 8     91000         8
# 2     57000         5
# 14    82450         7
# 1     35000         3
# 15    25400         3
# 19    52000         5

# %%
clf.predict(X_test)
# Out:
# array([13267.71233499, 26598.58519422, 16441.27485697, 35181.62735639,
#        39562.19966963, 28880.13327403])

# %%
y_test
# Out:
# 8     12000
# 2     26100
# 14    19400
# 1     34000
# 15    35000
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
clf.score(X_test, y_test)
# Out:
# 0.9144697939303547

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size = 0.3, random_state=10)
X_test
# Out:
#     Mileage  Age(yrs)
# 7     72000         6
# 10    83000         7
# 5     59000         5
# 6     52000         5
# 3     22500         2
# 18    87600         8
